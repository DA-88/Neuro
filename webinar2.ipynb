# %%
#!c1.8
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from PIL import Image
import numpy as np
import os
import random

# %% [markdown]
# #### Готовим списки

# %%
#!c1.8
i = 0
x_train = []
y_train = []
x_test  = []
y_test  = []

while i <= 9:
    for root, dirs, files in os.walk(f"train_captcha/{i}"):
      for file in files:
        y_train.append(i)
        with Image.open(os.path.join(root, file)) as a:     
            x_train.append(np.array(a))    

    for root, dirs, files in os.walk(f"test_captcha/{i}"):
      for file in files:
        y_test.append(i)
        with Image.open(os.path.join(root, file)) as a:     
            x_test.append(np.array(a))
             
    i += 1

# %%
#!c1.8
t = list(zip(x_train, y_train))
random.shuffle(t)
x_train1=[]
y_train1=[]
for tt in t:
    x_train1.append(tt[0])
    y_train1.append(tt[1])

# %%
#!c1.8
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(44, 24)),
    keras.layers.Dense(528, activation='tanh'),
    keras.layers.Dense(264, activation='tanh'),
    keras.layers.Dense(132, activation='tanh'),
    keras.layers.Dense(66, activation='tanh'),
    keras.layers.Dense(33, activation='tanh'),
    keras.layers.Dense(10,  activation='softmax')
])

model.compile(optimizer = 'adam',
              loss='categorical_crossentropy',
              metrics = ['accuracy'])

# %%
#!c1.8
model.fit(np.array(x_train1), to_categorical(y_train1), epochs=32, batch_size=32, use_multiprocessing=True, shuffle=True, verbose=1)
# Out:
# Epoch 1/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.3391 - accuracy: 0.8803
# Epoch 2/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.3142 - accuracy: 0.8978
# Epoch 3/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.4994 - accuracy: 0.7647
# Epoch 4/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.5266 - accuracy: 0.7692
# Epoch 5/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.3624 - accuracy: 0.9141
# Epoch 6/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.4194 - accuracy: 0.8592
# Epoch 7/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.5334 - accuracy: 0.7793
# Epoch 8/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.3918 - accuracy: 0.8713
# Epoch 9/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.3743 - accuracy: 0.8628
# Epoch 10/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.2942 - accuracy: 0.9183
# Epoch 11/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.2136 - accuracy: 0.9507
# Epoch 12/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.2042 - accuracy: 0.9535
# Epoch 13/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.2464 - accuracy: 0.9438
# Epoch 14/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.4769 - accuracy: 0.8007
# Epoch 15/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.7372 - accuracy: 0.6707
# Epoch 16/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.9055 - accuracy: 0.5968
# Epoch 17/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.7248 - accuracy: 0.6506
# Epoch 18/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.9034 - accuracy: 0.6415
# Epoch 19/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.8575 - accuracy: 0.6455
# Epoch 20/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.8344 - accuracy: 0.6520
# Epoch 21/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.8955 - accuracy: 0.5831
# Epoch 22/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.7940 - accuracy: 0.6303
# Epoch 23/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.8213 - accuracy: 0.6736
# Epoch 24/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.6405 - accuracy: 0.7411
# Epoch 25/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.6650 - accuracy: 0.7172
# Epoch 26/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.5731 - accuracy: 0.7536
# Epoch 27/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 0.9060 - accuracy: 0.5645
# Epoch 28/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 1.3990 - accuracy: 0.3042
# Epoch 29/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 1.6832 - accuracy: 0.1992
# Epoch 30/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 1.6829 - accuracy: 0.1991
# Epoch 31/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 1.6825 - accuracy: 0.2026
# Epoch 32/32
# 1329/1329 [==============================] - 3s 2ms/step - loss: 1.6806 - accuracy: 0.1997

# %%
#!c1.8
model.evaluate(np.array(x_test), to_categorical(y_test))
# Out:
# 235/235 [==============================] - 0s 1ms/step - loss: 0.4902 - accuracy: 0.7860
# [0.49016639590263367, 0.7860000133514404]
